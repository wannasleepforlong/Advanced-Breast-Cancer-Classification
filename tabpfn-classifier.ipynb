# %%
# !pip install tabpfn
# Out:
# Requirement already satisfied: tabpfn in /opt/conda/lib/python3.10/site-packages (6.0.6)
# Requirement already satisfied: torch<3,>=2.1 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (2.1.2+cpu)
# Requirement already satisfied: numpy<3,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (1.24.4)
# Requirement already satisfied: scikit-learn<1.8,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.12.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: scipy<2,>=1.11.1 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (1.11.4)
# Requirement already satisfied: pandas<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (2.2.0)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (0.8.1)
# Requirement already satisfied: huggingface-hub<2,>=0.19.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (0.20.3)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (2.12.4)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (2.12.0)
# Requirement already satisfied: eval-type-backport>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (0.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (1.3.2)
# Requirement already satisfied: tabpfn-common-utils>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (0.2.10)
# Requirement already satisfied: kditransform>=1.2 in /opt/conda/lib/python3.10/site-packages (from tabpfn) (1.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2023.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (21.3)
# Requirement already satisfied: numba>=0.48 in /opt/conda/lib/python3.10/site-packages (from kditransform>=1.2->tabpfn) (0.58.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.4.0->tabpfn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.4.0->tabpfn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.4.0->tabpfn) (2023.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.8.0->tabpfn) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.8.0->tabpfn) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from pydantic-settings>=2.10.1->tabpfn) (1.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.8,>=1.2.0->tabpfn) (3.2.0)
# Requirement already satisfied: platformdirs>=4 in /opt/conda/lib/python3.10/site-packages (from tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (4.1.0)
# Requirement already satisfied: posthog~=6.7 in /opt/conda/lib/python3.10/site-packages (from tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (6.9.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn) (3.1.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.48->kditransform>=1.2->tabpfn) (0.41.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub<2,>=0.19.0->tabpfn) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (1.16.0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<3,>=2.1->tabpfn) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<3,>=2.1->tabpfn) (1.3.0)

# %%
from tabpfn import TabPFNClassifier

# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/breast-cancer-wisconsin-data/data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(columns=['id'])
data = data.drop(columns=['Unnamed: 32'])

# %%
X = data.drop('diagnosis', axis=1)
y = data['diagnosis']
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from kaggle_secrets import UserSecretsClient
import os
user_secrets = UserSecretsClient()

# Set your HF token & username as environment variables
os.environ["HF_TOKEN"] = user_secrets.get_secret("huggingface")
# Replace with your username)
os.environ["HF_USERNAME"] = "megrisdal"
# !huggingface-cli whoami
# Out:
# sh221b777

# %%
classifier = TabPFNClassifier(device='cpu')

# %%
classifier.fit(X_train, y_train)
# Out:
# tabpfn-v2.5-classifier-v2.5_default.ckpt:   0%|          | 0.00/42.9M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/tabpfn/classifier.py:616: UserWarning: Running on CPU with more than 200 samples may be slow.
# Consider using a GPU or the tabpfn-client API: https://github.com/PriorLabs/tabpfn-client
#   check_cpu_warning(
# TabPFNClassifier(device='cpu')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve
import seaborn as sns
import matplotlib.pyplot as plt
import time
name = "TabPFN"

results = {}

model = classifier
start_pred_time = time.time()
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]
pred_time = time.time() - start_pred_time
# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
print(f"Latency: {pred_time:.4f}")
# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title(f"Confusion Matrix - {name}")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label="M")
plt.plot(fpr, tpr, label=f'{name} (AUC={roc_auc:.2f})')
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"ROC Curve - {name}")
plt.legend()
plt.show()

# Save accuracy
results[name] = accuracy

# Separator
print("*" * 50)
# Out:
# Accuracy: 0.9825
# Latency: 43.4971
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.97      1.00      0.99        71
#            M       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
# **************************************************
